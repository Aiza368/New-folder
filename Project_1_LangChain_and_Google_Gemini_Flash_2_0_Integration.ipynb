# %% [markdown]
# <a href="https://colab.research.google.com/github/Aiza368/New-folder/blob/main/Project_1_LangChain_and_Google_Gemini_Flash_2_0_Integration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')

# %%
# !pip install langchain_google_genai

# %%
from langchain_google_genai import GoogleGenerativeAI

# %% [markdown]
# ***Set Up Your Environment***

# %%
from langchain.prompts import PromptTemplate

# %% [markdown]
# ## *Configure the Gemini Flash Model*

# %%
llm = GoogleGenerativeAI(
    api_key= GOOGLE_API_KEY,
    model="gemini-2.0-flash-exp",
    temperature= 1
)

# %% [markdown]
# # ***Create a Prompt Template***

# %%
prompt_template = PromptTemplate(
    input_variables=["question"],
    template="You are a helpful assistant. Answer the following question:\n\n{question}"
)

# %% [markdown]
# # ***Creating LLMChain***

# %%
Chain = prompt_template | llm

# %% [markdown]
# # ***Running chain with questions***

# %%
questions = [
    "What is the capital of France?"
    "Explain the theory of relativity in simple terms."
    "What are the key benefits of using AI in healthcare?"
]

# %% [markdown]
# # ***Display the model's responses ***

# %%
for i in questions:
    response= Chain.invoke({i})
    print(f"Question: {i}")
    print(f"Answer: {response}\n")
# Out:
# Question: What is the capital of France?Explain the theory of relativity in simple terms.What are the key benefits of using AI in healthcare?
# Answer: Okay, let's break down these questions one by one:
#
# **1. What is the capital of France?**
#
# The capital of France is **Paris**.
#
# **2. Explain the theory of relativity in simple terms.**
#
# The theory of relativity, developed by Albert Einstein, actually consists of two interconnected theories: special relativity and general relativity. Here's a very simplified explanation of each:
#
# *   **Special Relativity:** This theory deals with the relationship between space and time. It states that:
#     *   **The speed of light is constant for all observers, regardless of their motion.** This is a mind-bending concept! It means that whether you're standing still or moving incredibly fast, you'll always measure the speed of light to be the same.
# ...

# %% [markdown]
# # ***Using other templates and parameters***

# %%
llm = GoogleGenerativeAI(
    api_key= GOOGLE_API_KEY,
    model="gemini-2.0-flash-exp",
    temperature=1,
    top_p=0.7,
    tokens=100
)

# %%
prompt_template = PromptTemplate(
    input_variables=["question"],
    template="You are a creative AI assistant. Use imagination and creativity to provide engaging and insightful answers to the user's questions.:\n\n{question}"
)

# %%
Chain = prompt_template | llm

# %%
questions = [
    "What are benefits of AI?"
    "I am having Headache what should I do?"
    "Tell me joke"
]

# %%
for i in questions:
    response= Chain.invoke({i})
    print(f"Question: {i}\n")
    print(f"Answer: {response}\n")
# Out:
# Question: What are benefits of AI?I am having Headache what should I do?Tell me joke
#
# Answer: Okay, let's tackle this trio of questions with a dash of imagination and a sprinkle of fun!
#
# **The Marvelous Benefits of AI: A Symphony of Possibilities**
#
# Imagine AI not as a cold, calculating machine, but as a vibrant orchestra, each instrument playing a vital role in a grand symphony of progress. Here are some of the enchanting melodies it can create:
#
# *   **The Maestro of Efficiency:** AI can automate repetitive tasks, freeing up human minds to explore creativity and innovation. Think of it as a tireless assistant, handling the mundane so you can focus on the magnificent.
# *   **The Oracle of Insight:** AI can analyze vast amounts of data, revealing hidden patterns and insights that would be impossible for humans to uncover alone. It's like having a magical magnifying glass, illuminating the secrets of the universe.
# ...

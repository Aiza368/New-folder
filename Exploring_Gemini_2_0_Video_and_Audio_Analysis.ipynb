# %% [markdown]
# <a href="https://colab.research.google.com/github/Aiza368/New-folder/blob/main/Exploring_Gemini_2_0_Video_and_Audio_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade --quiet google-genai

# %%
from google.colab import userdata
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')

# %%
from google import genai
from google.genai import Client

client: Client = genai.Client(
    api_key=GOOGLE_API_KEY,
)

model: str = "gemini-2.0-flash-exp"

# %%
from google.colab import files
uploaded = files.upload()
for filename in uploaded.keys():
  print(f"Uploaded file:{filename}")
# Out:
#      <input type="file" id="files-16b8b6a5-494d-4aaf-a0b9-26b5a9354a37" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-16b8b6a5-494d-4aaf-a0b9-26b5a9354a37">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import time

def upload_video(video_file_name):
  video_file = client.files.upload(path="VIdeo for assignment.mp4")
  while video_file.state == "PROCESSING":
      print('Waiting for video to be processed.')
      time.sleep(10)
      video_file = client.files.get(name=video_file.name or "")

  if video_file.state == "FAILED":
    raise ValueError(video_file.state)
  print(f'Video processing complete: ' + (video_file.uri or ""))

  return video_file

Video = upload_video('VIdeo for assignment.mp4')
# Out:
# Waiting for video to be processed.
# Video processing complete: https://generativelanguage.googleapis.com/v1beta/files/u2yh8l8efhe3

# %%
from google.genai.types import Content, Part
from IPython.display import Markdown
prompt = """For each scene in this video,
            generate captions that describe the scene along with any spoken text placed in quotation marks.
            Place each caption into an object with the timecode of the caption in the video.
         """

video = Video

response = client.models.generate_content(
    model=model,
    contents=[
        Content(
            role="user",
            parts=[
                Part.from_uri(
                     file_uri=video.uri or "",
                    mime_type=video.mime_type or ""),
                ]),
        prompt,
    ]
)

Markdown(response.text)
# Out:
# ```json
# [
#   {
#     "timecode": "0:00",
#     "caption": "A woman with long brown hair is facing forward and speaking directly to the camera. She is wearing a light blue striped shirt. The text 'BASIC VS SLANG' is displayed on the screen using orange and pink shapes. The text 'ALBERT LEARNING' is displayed at the top right in red."
#   },
#   {
#     "timecode": "0:02",
#      "caption": "The woman is wearing a beige sweater and is looking to the right of the frame.  A white circle with the number one is displayed above the text ‘TALKATIVE’ in a pink rectangle. There is also a framed picture on the wall behind her."
#   },
#   {
#     "timecode": "0:04",
#     "caption": "The woman is now wearing a red and white patterned jacket over a white shirt. She is looking to the left of the frame.  A white circle with the number one is displayed above the text ‘CHATTY’ in a red rectangle. A colorful artwork is also slightly visible in the background."
#   },
#   {
# ...
